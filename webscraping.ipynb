# %%
from urllib.request import urlopen

# %%
url = "http://olympus.realpython.org/profiles/aphrodite"

# %%
page = urlopen(url)
page

# %%
html_bytes = page.read()
html = html_bytes.decode("utf-8")
print(html)
# Out:
# <html>
# <head>
# <title>Profile: Aphrodite</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br><br>
# <img src="/static/aphrodite.gif" />
# <h2>Name: Aphrodite</h2>
# <br><br>
# Favorite animal: Dove
# <br><br>
# Favorite color: Red
# <br><br>
# Hometown: Mount Olympus
# </center>
# </body>
# </html>

# %%
title_index = html.find("<title>")
title_index
# Out:
# 14

# %%
start_index = title_index + len("<title>")
end_index = html.find("</title>")
title = html[start_index:end_index]

# %%
import re
from urllib.request import urlopen

url = "http://olympus.realpython.org/profiles/dionysus"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = "<title.*?>.*?</title.*?>"
match_results = re.search(pattern, html, re.IGNORECASE)
title = match_results.group()
title = re.sub("<.*?>", "", title) # Remove HTML tags

print(title)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = "http://olympus.realpython.org/profiles/dionysus"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
print(soup.get_text())
# Out:
# Profile: Dionysus
#
#
#
#
#
# Name: Dionysus
#
# Hometown: Mount Olympus
#
# Favorite animal: Leopard
#
# Favorite Color: Wine

# %%
soup.find_all("img")
# Out:
# [<img src="/static/dionysus.jpg"/>, <img src="/static/grapes.png"/>]

# %%
image1, image2 = soup.find_all("img")

# %%
soup.title
# Out:
# <title>Profile: Dionysus</title>

# %%
soup.find_all("img", src="/static/dionysus.jpg")
# Out:
# [<img src="/static/dionysus.jpg"/>]

# %%
import mechanicalsoup

# 1
browser = mechanicalsoup.Browser()
url = "http://olympus.realpython.org/login"
login_page = browser.get(url)
login_html = login_page.soup

# 2
form = login_html.select("form")[0]
form.select("input")[0]["value"] = "zeus"
form.select("input")[1]["value"] = "ThunderDude"

# 3
profiles_page = browser.submit(form, login_page.url)

# %%
profiles_page.url
# Out:
# 'http://olympus.realpython.org/profiles'

# %%
links = profiles_page.soup.select("a")

# %%
import mechanicalsoup

browser = mechanicalsoup.Browser()
page = browser.get("http://olympus.realpython.org/dice")
tag = page.soup.select("#result")[0]
result = tag.text

print(f"The result of your dice roll is: {result}")
# Out:
# The result of your dice roll is: 3

# %%
import time
import mechanicalsoup

browser = mechanicalsoup.Browser()

for i in range(4):
    page = browser.get("http://olympus.realpython.org/dice")
    tag = page.soup.select("#result")[0]
    result = tag.text
    print(f"The result of your dice roll is: {result}")
    time.sleep(10)
# Out:
# The result of your dice roll is: 5
# The result of your dice roll is: 1
# The result of your dice roll is: 5
# The result of your dice roll is: 1

# %%
import time
import mechanicalsoup

browser = mechanicalsoup.Browser()

for i in range(4):
    page = browser.get("http://olympus.realpython.org/dice")
    tag = page.soup.select("#result")[0]
    result = tag.text
    print(f"The result of your dice roll is: {result}")

    # Wait 10 seconds if this isn't the last request
    if i < 3:
        time.sleep(10)
# Out:
# The result of your dice roll is: 3
# The result of your dice roll is: 6
# The result of your dice roll is: 2
# The result of your dice roll is: 3

# %% [markdown]
# ## Own stuff:

# %%
url = "https://www.spiegel.de/politik/ausland/alexej-nawalny-unterstuetzer-provozieren-wladimir-putin-mit-herzchen-protest-a-f872b1ec-2ac2-43cc-b396-76f0c2f889f4"

browser = mechanicalsoup.Browser()

page = browser.get(url)
#tag = page.soup.select("#result")[0]

# %%
page.soup
# Out:
# <!DOCTYPE html>
# <html class="brand-spon" lang="de">
# <head>
# <title>Alexej Nawalny: Unterstützer provozieren Wladimir Putin mit Herzchen-Protest - DER SPIEGEL</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,user-scalable=no" name="viewport"/>
# <meta content="true" name="MSSmartTagsPreventParsing"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="IE=Edge" http-equiv="x-ua-compatible"/>
# <meta content="app-id=424881832" name="apple-itunes-app"/>
# <link href="https://www.spiegel.de/public/spon/json/manifest.json" rel="manifest"/>
# <meta content="#E64415" name="theme-color"/>
# <meta content="lwpSnwoyvMkHS9nHmLBZuYOashAHfooOHSHeA_KS7ek" name="google-site-verification"/>
# <meta content="index, follow, noarchive, noodp, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <meta content="index, follow" name="Googlebot-News"/>
# <meta content="DER SPIEGEL, Hamburg, Germany" name="copyright"/>
# <meta content="spiegel_online@spiegel.de" name="email"/>
# <meta content="DER SPIEGEL" name="author"/>
# <meta content="2021-02-14T21:21:12+01:00" name="date"/>
# <meta content="2021-02-14T21:21:12+01:00" name="last-modified"/>
# <meta content="de_DE" name="locale"/>
# <meta content="Am Valentinstag haben Menschen in Russland gegen die Inhaftierung von Alexej Nawalny demonstriert. Kremlchef Putin sprach im Staatsfernsehen von »unseren Gegnern«." name="description"/>
# <meta content="Politik, Ausland, Alexej Nawalny, Opposition in Russland, Russland, Wladimir Putin" name="news_keywords"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@derspiegel" name="twitter:site"/>
# <meta content="Russland: Nawalny-Unterstützer provozieren Putin mit Herzchen-Protest" name="twitter:title"/>
# <meta content="@derspiegel" name="twitter:creator"/>
# <meta content="https://cdn.prod.www.spiegel.de/images/5c4baa9d-7090-44b9-ac33-a181beaba8a8_w1280_r1.77_fpx50.67_fpy50.jpg" name="twitter:image"/>
# <meta content="Russland: Nawalny-Unterstützer provozieren Putin mit Herzchen-Protest" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.spiegel.de/politik/ausland/alexej-nawalny-unterstuetzer-provozieren-wladimir-putin-mit-herzchen-protest-a-f872b1ec-2ac2-43cc-b396-76f0c2f889f4" property="og:url"/>
# <meta content="https://cdn.prod.www.spiegel.de/images/5c4baa9d-7090-44b9-ac33-a181beaba8a8_w1280_r1.77_fpx50.67_fpy50.jpg" property="og:image"/>
# <meta content="Am Valentinstag haben Menschen in Russland gegen die Inhaftierung von Alexej Nawalny demonstriert. Kremlchef Putin sprach im Staatsfernsehen von »unseren Gegnern«." property="og:description"/>
# <script type="application/ld+json">
# [
# <style>
#                 html.overlay-open {
#     overflow: hidden !important;
# }
#
# html.is-logged-in [data-logged-in-hidden] {
#     display: none;
# }
#
# html:not(.is-logged-in) [data-not-logged-in-hidden] {
#     display: none;
# }
#
# html.is-mobile [data-mobile-hidden] {
#     display: none;
# }
#
# html.is-tablet [data-tablet-hidden] {
#     display: none;
# }
#
# html:not(.is-mobile) [data-not-mobile-hidden] {
#     display: none;
# }
#
# html.is-app [data-app-hidden] {
#     display: none;
# }
#
# html:not(.is-ios) [data-not-ios-hidden] {
#     display: none;
# }
#
# html.is-app [data-app-headerbar-offset] {
#     top: 0;
# }
#
# html:not(.is-app) [data-anchor-offset]::before {
#     content: "";
#     display: block;
# }
#
# html.is-app {
#     -webkit-tap-highlight-color: transparent;
# }
#
# html:not(.is-app) [data-not-app-hidden] {
#     display: none;
# }
#
# html.hide-conditional [data-contains-flags*="conditional"] [data-flag-name*="conditional"],
# html.hide-conditional [data-contains-flags="sponconditional"],
# html.hide-conditional [data-contains-flags="deinconditional"],
# html.hide-conditional [data-contains-flags="mmoconditional"],
# html.hide-conditional [data-contains-flags="hbmconditional"] {
#     display: none;
# }
# html:not(.hide-conditional) [data-contains-flags*="conditional"] [data-flag-name="spon"],
# html:not(.hide-conditional) [data-contains-flags*="conditional"] [data-flag-name="dein"],
# html:not(.hide-conditional) [data-contains-flags*="conditional"] [data-flag-name="mmo"],
# html:not(.hide-conditional) [data-contains-flags*="conditional"] [data-flag-name="hbm"] {
#     display: none;
# }
#
# html.has-breaking-news [data-has-breaking-news-hidden] {
#     display: none;
# }
#
# html.has-paid-access [data-has-paid-access-hidden] {
#     display: none;
# }
#
# html:not(.has-paid-access) [data-has-no-paid-access-hidden] {
#     display: none;
# }
#
# html:not(.has-consent) [data-has-no-consent-hidden] {
#     display: none;
# }
#
# [data-component="BreakpointListener"]::before {
#     display: none;
#     content: "sm"
# }
#
# @media (min-width: 720px) {
#     [data-component="BreakpointListener"]::before {
#         content: "md"
#     }
# }
#
# [data-advertisement^="GujAd"] .teads-inread,
# .RichText .teads-inread {
#     margin-bottom: 24px !important;
# }
# [data-advertisement^="GujAd"].unhidable {
#     display: block !important;
# }
#
# .gujAd[id^="maxiad_"],
# .gujAd[id^="superbanner_"],
# .gujAd[id^="mobile_"],
# .gujAd#dmofooter_1,
# .gujAd#teaser_11,
# .gujAd#rectangle_1,
# .gujAd#rectangle_2,
# .gujAd#rectangle_21,
# .gujAd#rectangle_22 {
#     text-align: center;
#     margin-left: auto;
#     margin-right: auto;
# }
# .gujAd[id^="maxiad_"] iframe[id*="google_ads_iframe"],
# .gujAd[id^="superbanner_"] iframe[id*="google_ads_iframe"],
# .gujAd[id^="mobile_"] iframe[id*="google_ads_iframe"],
# .gujAd#dmofooter_1 iframe[id*="google_ads_iframe"],
# .gujAd#teaser_11 iframe[id*="google_ads_iframe"],
# .gujAd#rectangle_1 iframe[id*="google_ads_iframe"],
# .gujAd#rectangle_2 iframe[id*="google_ads_iframe"],
# .gujAd#rectangle_21 iframe[id*="google_ads_iframe"],
# .gujAd#rectangle_22 iframe[id*="google_ads_iframe"] {
#     margin-left: auto;
#     margin-right: auto;
# }
#
# a > svg:first-of-type:last-of-type {
#     pointer-events: none;
# }
#                 html:not(.is-app) [data-app-headerbar-offset] {
#     top: 48px;
# }
#
# html:not(.is-app) [data-anchor-offset]::before {
#     margin-top: -108px;
#     height: 108px;
# }
#
# @media (max-width: 719px) {
#     html:not(.is-app) [data-anchor-offset]::before {
#         margin-top: -100px;
#         height: 100px;
#     }
# }
#
# @media (min-width: 1012px) {
#     html.has-marginal-column [data-area="news-section"] [data-size="full"]:not([data-first="true"])::before,
#     html.has-marginal-column [data-area="news-section"] [data-size="full"]:not([data-last="true"])::after {
#         content: "";
#         position: absolute;
#         width: calc(100% + 8px);
#         height: 24px;
#         z-index: 1;
#     }
#
#     html.has-marginal-column [data-size="full"]:not([data-first="true"])::before {
#         top: -24px;
#         right: -4px;
#         background: linear-gradient(to top, rgba(241, 239, 237, 1) 0, rgba(241, 239, 237, 0) 100%);
#     }
#
#     html.has-marginal-column [data-size="full"]:not([data-last="true"])::after {
#         width: calc(100% + 8px);
#         bottom: -24px;
#         right: -4px;
#         background-image: linear-gradient(to bottom, rgba(241, 239, 237, 1) 0, rgba(241, 239, 237, 0) 100%);
#     }
#
#     [data-component="BreakpointListener"]::before {
#         content: "lg"
#     }
# }
#             </style>
# <link href="https://cdn.prod.www.spiegel.de/public/spon/generated/css/spon/generated/css/styles.spon.342de804a5412c48c95f.css" rel="stylesheet"/>
# <link href="https://cdn.prod.www.spiegel.de/public/mmo/generated/css/styles.spon-sm.4601141bdcca4ea470b2.css" media="(max-width:719px)" rel="stylesheet"/>
# <link href="https://cdn.prod.www.spiegel.de/public/mmo/generated/css/styles.spon-md.2e0058a3a84b481c74b3.css" media="(min-width:720px) and (max-width:1011px)" rel="stylesheet"/>
# <link href="https://cdn.prod.www.spiegel.de/public/mmo/generated/css/styles.spon-lg.0bdcf2f1684b35d236cd.css" media="(min-width:1012px)" rel="stylesheet"/>
# <script type="application/settings+json">{"general":{"cacheControl":{"breakingnews":{"sessionStorageMaxAge":900}},"consent":{"disabled":false,"minUpdatedAt":1607382001},"disableAds":false,"domain":"spon","noAds":false,"products":{"noads":"Sppur","paid":"Spplus"},"redirectConsentEnabled":true,"secondLevelDomain":"spiegel","topLevelDomain":"de","urls":{"account":{"account":"https://gruppenkonto.spiegel.de/meinkonto/uebersicht.html","login":"https://gruppenkonto.spiegel.de/authenticate?requestAccessToken=true\u0026targetUrl=https%3A%2F%2Fwww.spiegel.de%2Fpolitik%2Fausland%2Falexej-nawalny-unterstuetzer-provozieren-wladimir-putin-mit-herzchen-protest-a-f872b1ec-2ac2-43cc-b396-76f0c2f889f4","logout":"https://gruppenkonto.spiegel.de/abmelden.html?targetUrl=https%3A%2F%2Fwww.spiegel.de%2F","register":"https://gruppenkonto.sp
# ,"guj":{"isIndexPage":false,"keywords":["Politik","Ausland","Alexej Nawalny","Opposition in Russland","Russland","Wladimir Putin","nextgen"],"spmard":"f872b1ec-2ac2-43cc-b396-76f0c2f889f4","spmtid":"alexej_nawalny,oppositionsbewegung_in_russland,russland,wladimir_putin","spmtp":"default","spmurid":"ausland","zone":"politik"}
# ,"page":{"attributes":{"channel_slug":"politik","is_consent_required":true,"subchannel_slug":"ausland"},"category":{"route":"article"},"info":{"canonical_url":"https://www.spiegel.de/politik/ausland/alexej-nawalny-unterstuetzer-provozieren-wladimir-putin-mit-herzchen-protest-a-f872b1ec-2ac2-43cc-b396-76f0c2f889f4","domain":"spon","language":"de","title":"Alexej Nawalny: Unterstützer provozieren Wladimir Putin mit Herzchen-Protest"}}
# ,"external":{}
# ,"editorial":{"attributes":{"has_affiliate":false,"has_author":false,"has_gallery":false,"has_noAds":false,"has_noContentAds":false,"has_video":false,"is_breaking":false,"is_comments_enabled":true,"is_evergreen":false,"is_exclusive":false,"is_listExcluded":false,"is_noted":false,"magazine":""},"author":{"abbreviation":"fdi/dpa","departments":["Ausland"],"names":[]},"category":{"genre":"Nachricht","style":"default","type":"news"},"info":{"article_id":"f872b1ec-2ac2-43cc-b396-76f0c2f889f4","channel":"Politik","date_modified":"2021-02-14T21:21:12+01:00","date_published":"2021-02-14T21:21:12+01:00","header_image_id":"5c4baa9d-7090-44b9-ac33-a181beaba8a8","headline":"Putin genervt: Nawalny-Unterstützer protestieren mit Herz und Taschenlampe","headline_social":"Russland: Nawalny-Unterstützer provozieren Putin mit Herzchen-Protest","intro":"Am Valentinstag haben Menschen in Russland gegen die Inhaftierung von Alexej Nawalny demonstriert. Kremlchef Putin sprach im Staatsfernsehen von »unseren Gegnern«.","subchannel":"Ausland","topics":["Alexej Nawalny","Opposition in Russland","Russland","Wladimir Putin"]}}
# ,"paywall":{"attributes":{"is_active":false},"category":{"type":"free"},"info":{"position":"na"}}
# ,"video":{}
# }</script>
# <script>!function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();</script>
# <script>window.SARAs_data = window.SARAs_data || [];</script>
# <script src="https://cdn.prod.www.spiegel.de/public/shared/generated/js/commons.f6a41591a1db90303b1e.js"></script>
# <script src="https://cdn.prod.www.spiegel.de/public/shared/generated/js/header.7a5bb347c6fae424e4c8.js"></script>
# <script>
#     var GujAd = GujAd || {};
#     GujAd.cmd = GujAd.cmd || [];
#     var GujAdPositions = GujAdPositions || [];
# </script>
# <script>!function(e,a){var t="at-body-style";function n(){return a.getElementsByTagName("head")[0]}!function(e,t,n){if(e){var i=a.createElement("style");i.id=t,i.innerHTML=n,e.appendChild(i)}}(n(),t,"[data-target-hide] {opacity: 0 !important}"),setTimeout(function(){!function(e,t){if(e){var n=a.getElementById(t);n&&e.removeChild(n)}}(n(),t)},1000)}(window,document);</script>
# </head>
# <body class="bg-shade-lightest relative min-w-sm leading-normal static antialiased lining-nums lg:overflow-x-hidden lg:overflow-y-scroll" data-advertisement="SP background" data-area="article:alexej-nawalny-unterstuetzer-provozieren-wladimir-putin-mit-herzchen-protest" data-component="EventObserver">
# <div class="OffsetContainer flex justify-end relative">
# <span class="relative w-full relative">
# <a class="SkipLink absolute bg-shade-lightest bg-white font-bold font-sansUI inline-block sm:mr-8 md:mr-24 lg:mr-24 sm:mt-8 md:mt-12 lg:mt-12 sm:top-0 md:top-80 lg:top-80 right-0 pointer-events-auto px-12 py-8 rounded text-primary-darker text-s z-overlay" href="#Inhalt" title="Zum Inhalt springen">Zum Inhalt springen</a>
# </span>
# </div>
# <div data-component="BreakpointListener"></div>
# <div class="absolute top-0 h-px w-full invisible" data-app-hidden="" data-body-el="scrollObserver"></div>
# <header class="sticky top-0 -mt-8 z-30 pointer-events-none" data-stickyfill="" role="banner">
# <div data-app-hidden="">
# <div class="relative z-max" data-area="header-bar">
# <div class="bg-primary-base top-0 w-full z-10 pointer-events-auto" data-component="HeaderBar">
# <div class="OffsetContainer bg-primary-base md:overflow-hidden lg:overflow-hidden">
# <div class="lg:max-w-lg mx-auto flex items-center lg:px-32 md:px-24 lg:py-20 md:py-20 sm:pb-12 sm:pl-16 sm:pr-12 sm:pt-12 lg:h-80 md:h-80 sm:h-48" data-headerbar-el="inner">
# <span class="flex flex-auto justify-between items-center md:order-1 lg:order-1 overflow-hidden" data-headerbar-el="logo">
# <span class="text-white flex-shrink-0">
# <a aria-label="DER SPIEGEL" href="https://www.spiegel.de/" target="_self" title="DER SPIEGEL">
# <span class="hidden">DER SPIEGEL</span>
# <span class="block lg:hidden md:hidden leading-none"><svg aria-labelledby="title-0a676037-c0ab-483d-ac85-b4f46d191b26" fill="none" height="15" role="img" viewbox="0 0 74 15" width="74" xmlns="http://www.w3.org/2000/svg"><title id="title-0a676037-c0ab-483d-ac85-b4f46d191b26">Der Spiegel</title><g clip-path="url(#clip0-0a676037-c0ab-483d-ac85-b4f46d191b26)" id="spiegel-mobile-0a676037-c0ab-483d-ac85-b4f46d191b26"><g id="der-spiegel-tablet-desktop-0a676037-c0ab-483d-ac85-b4f46d191b26"><g fill="#fff" id="logo-0a676037-c0ab-483d-ac85-b4f46d191b26"><path d="M-36.635 12.5v-10h3.212v10h-3.212zm6.123.9V1.6c0-.9-.803-1.6-1.606-1.6h-8.632v2.5h1.205v10h-1.205V15h8.733c.803 0 1.505-.7 1.505-1.6zM-21.478 9.7v2.8h-3.413V8.4h4.517V5.9h-4.517V2.5h3.413v2.1h2.81V0h-10.238v2.5h1.104v10h-1.104V15h10.238V9.7h-2.81zM-13.047 5.9V2.5h3.313v3.4h-3.313zm6.324 6.6V8.9c0-.9-.703-1.6-1.606-1.6.903 0 1.606-.7 1.606-1.6v-4c0-.8-.703-1.6-1.506-1.6h-8.933v2.5h1.305v10h-1.305V15h5.32v-2.5h-1.104V8.4h3.312v4.1h-1.205V15h5.22v-2.5h-1.104zM14.656 5.9V2.5h3.413v3.4h-3.413zm6.324.9V1.6c0-.9-.703-1.6-1.606-1.6H10.54v2.5h1.204v10h-1.204V15h5.22v-2.5h-1.105V8.4h4.718c.903 0 1.606-.7 1.606-1.6zM26.099 12.5v-10h1.204V0h-5.22v2.5
# </span>
# </a>
# </span>
# <a class="relative mr-auto ml-4 mt-2 text-white overflow-hidden pr-16 font-sans text-3xl ml-6 sm:overflow-x-auto sm:text-l sm:leading-normal sm:ml-4 tracking-wide whitespace-no-wrap" href="https://www.spiegel.de/politik/" target="_self" title="Politik">
# Politik
# </a>
# <div class="relative lg:h-56 md:h-56 sm:h-40 focus:outline-none">
# <div class="z-10 absolute right-0 bottom-0 lg:h-56 md:h-56 sm:h-40">
# <div class="flex items-center">
# <span class="bg-headerLeftToRight w-24 lg:h-56 md:h-56 sm:h-40"></span>
# </div>
# </div>
# </div>
# </span>
# <div class="flex items-center justify-end flex-auto md:order-2 lg:order-2" data-headerbar-el="controls">
# <a class="font-bold bg-primary-base inline-block text-white font-sansUI py-12 text-s sm:mr-24" href="https://abo.spiegel.de/?b=SPOHNAVABO&amp;requestAccessToken=true&amp;sara_icid=disp_upd_9h6L5hu8K1AAnttzYATx3hvk7taDkP&amp;targetUrl=https%3A%2F%2Fwww.spiegel.de%2Ffuermich%2F" target="_blank" title="Abonnement">
# <span class="sm:hidden border-b">Abonnement</span>
# <span class="lg:hidden md:hidden border-b">Abo</span>
# </a>
# <a class="sm:hidden font-bold bg-white inline-block disabled:bg-white disabled:text-shade-base disabled:cursor-not-allowed font-sansUI ml-24 px-16 py-12 text-s rounded text-primary-base hover:bg-white hover:text-primary-dark focus:text-primary-darker focus:bg-shade-lightest" data-logged-in-hidden="" data-sara-link="gruppenkonto" href="https://gruppenkonto.spiegel.de/authenticate?requestAccessToken=true&amp;targetUrl=https%3A%2F%2Fwww.spiegel.de%2Ffuermich%2F" title="Jetzt anmelden">
# <span class="flex">
# <span class="relative bottom-px">Anmelden</span>
# <span class="flex leading-none items-center ml-8"><svg aria-labelledby="title-73cc4eeb-049f-42dd-949b-a5ba2510ccef" class="stroke-current" fill="none" height="12" role="img" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg"><title id="title-73cc4eeb-049f-42dd-949b-a5ba2510ccef">Pfeil nach rechts</title><g id="s-chevron-right-f-73cc4eeb-049f-42dd-949b-a5ba2510ccef"><g id="s-chevron-right-73cc4eeb-049f-42dd-949b-a5ba2510ccef"><path d="M4.333 2.667L7.667 6 4.333 9.333" id="vector-73cc4eeb-049f-42dd-949b-a5ba2510ccef" stroke-linecap="round" stroke-width="1.5"></path></g></g></svg>
# </span>
# </span>
# </a>
# <a class="sm:hidden ml-24 bg-white h-40 inline-flex items-center justify-center rounded-circle w-40 md:hidden sm:hidden text-primary-base hover:opacity-distinct" data-not-logged-in-hidden="" href="https://www.spiegel.de/fuermich/" title="Für Mich"><svg aria-labelledby="title-e51c1dba-f2ed-4b04-ab13-3c5139ea66f6" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-e51c1dba-f2ed-4b04-ab13-3c5139ea66f6">Icon: Konto</title><path class="stroke-current" d="M8.05 8.5A3.917 3.917 0 0 1 12 4.55a3.917 3.917 0 0 1 3.95 3.95A3.917 3.917 0 0 1 12 12.45 3.917 3.917 0 0 1 8.05 8.5z" stroke-width="1.1"></path><mask fill="#fff" id="path-3-inside-1-e51c1dba-f2ed-4b04-ab13-3c5139ea66f6"><path clip-rule="evenodd" d="M19.9 20H21a5 5 0 0 0-5-5H8a5 5 0 0 0-5 5h1.1A3.9 3.9 0 0 1 8 16.1h8a3.9 3.9 0 0 1 3.9 3.9z" fill-rule="evenodd"></path></mask><path class="fill-current" d="M19.9 20h-1.3v1.3h1.3V20zm1.1 0v1.3h1.3V20H21zM3 20H1.7v1.3H3V20zm1.1 0v1.3h1.3V20H4.1zm15.8 1.3H21v-2.6h-1.1v2.6zm-3.9-5a3.7 3.7 0 0 1 3.7 3.7h2.6a6.3 6.3 0 0 0-6.3-6.3v2.6zm0-2.6H8v2.6h8v-2.6zM4.3 20A3.7 3.7 0 0 1 8 16.3v-2.6A6.3 6.3 0 0 0 1.7 20h2.6zM3 21.3h1.1v-2.6H3v2.6zm5-6.5A5.2 5.2 0 0 0 2.8 20h2.6A2.6 2.6 0 0 1 8 17.4v-2.6zm8 0H8v2.6h8v-2.6zm5.2 5.2a5.2 5.2 0 0 0-5.2-5.2v2.6a2.6 2.6 0 0 1 2.6 2.6h2.6z" mask="url(#path-3-inside-1-e51c1dba-f2ed-4b04-ab13-3c5139ea66f6)"></path></svg>
# </a>
# </div>
# <button aria-label="Menü öffnen" class="md:absolute lg:absolute md:h-full lg:h-full md:top-0 lg:top-0 lg:invisible md:invisible lg:opacity-none md:opacity-none md:-ml-4 lg:-ml-4 text-white leading-none outline-focus" data-headerbar-el="menuActivator" title="Menü öffnen">
# <span class="hidden">Menü öffnen</span><svg aria-labelledby="title-0795ce7c-8f22-4cef-b194-b58b22c83e78" class="stroke-current" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-0795ce7c-8f22-4cef-b194-b58b22c83e78">Icon: Menü</title><g id="l-menu-0795ce7c-8f22-4cef-b194-b58b22c83e78" stroke-linecap="round" stroke-width="1.3"><path d="M19.35 6.65H4.65" id="line-0795ce7c-8f22-4cef-b194-b58b22c83e78"></path><path d="M19.35 11.65H4.65" id="line_2-0795ce7c-8f22-4cef-b194-b58b22c83e78"></path><path d="M19.35 16.65H4.65" id="line_3-0795ce7c-8f22-4cef-b194-b58b22c83e78"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <nav class="z-10 mt-8" role="navigation">
# <div data-app-hidden="">
# <div class="w-full mb-px bg-white shadow" data-area="tab-bar">
# <ul class="flex items-center justify-around lg:hidden md:h-56 sm:h-48 mx-auto">
# <li data-target-hide="">
# <a aria-label="News" class="inline-flex md:p-12 sm:p-8 text-black" href="https://www.spiegel.de/" target="_self" title="News"><svg aria-labelledby="title-678e4ec4-e45c-4a59-bfa3-e0307ce97a08" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-678e4ec4-e45c-4a59-bfa3-e0307ce97a08">Icon: Startseite</title><path class="stroke-current" d="M4.5 10.5v9h6v-3a1 1 0 0 1 1-1h1a1 1 0 0 1 1 1v3h6v-9l-7.5-7-7.5 7z" stroke-width="1.1"></path></svg>
# <span class="hidden">News</span>
# </a>
# </li>
# <li data-target-hide="">
# <a aria-label="Ticker" class="inline-flex md:p-12 sm:p-8 text-black" href="https://www.spiegel.de/schlagzeilen/" target="_self" title="Ticker"><svg aria-labelledby="title-aa91c219-d38d-4676-a4b9-716c9569afc9" class="stroke-current" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"
fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-25cfc4aa-08a2-4e38-b603-20db15b19e17">Icon: Konto</title><path class="stroke-current" d="M8.05 8.5A3.917 3.917 0 0 1 12 4.55a3.917 3.917 0 0 1 3.95 3.95A3.917 3.917 0 0 1 12 12.45 3.917 3.917 0 0 1 8.05 8.5z" stroke-width="1.1"></path><mask fill="#fff" id="path-3-inside-1-25cfc4aa-08a2-4e38-b603-20db15b19e17"><path clip-rule="evenodd" d="M19.9 20H21a5 5 0 0 0-5-5H8a5 5 0 0 0-5 5h1.1A3.9 3.9 0 0 1 8 16.1h8a3.9 3.9 0 0 1 3.9 3.9z" fill-rule="evenodd"></path></mask><path class="fill-current" d="M19.9 20h-1.3v1.3h1.3V20zm1.1 0v1.3h1.3V20H21zM3 20H1.7v1.3H3V20zm1.1 0v1.3h1.3V20H4.1zm15.8 1.3H21v-2.6h-1.1v2.6zm-3.9-5a3.7 3.7 0 0 1 3.7 3.7h2.6a6.3 6.3 0 0 0-6.3-6.3v2.6zm0-2.6H8v2.6h8v-2.6zM4.3 20A3.7 3.7 0 0 1 8 16.3v-2.6A6.3 6.3 0 0 0 1.7 20h2.6zM3 21.3h1.1v-2.6H3v2.6zm5-6.5A5.2 5.2 0 0 0 2.8 20h2.6A2.6 2.6 0 0 1 8 17.4v-2.6zm8 0H8v2.6h8v-2.6zm5.2 5.2a5.2 5.2 0 0 0-5.2-5.2v2.6a2.6 2.6 0 0 1 2.6 2.6h2.6z" mask="url(#path-3-inside-1-25cfc4aa-08a2-4e38-b603-20db15b19e17)"></path></svg>
# <span class="hidden">Account</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="z-10 relative bg-white w-full shadow font-sans" data-app-hidden="" data-area="nav-bar" data-component="NavBar" data-settings='{"isBreadcrumb":true}'>
# <div class="OffsetContainer bg-white">
# <div class="lg:max-w-lg mx-auto font-sansUI flex items-center lg:h-56 md:h-56 sm:h-40 lg:pl-12 lg:pr-16 md:pl-4 md:pr-8">
# <div class="flex items-center sm:hidden lg:flex-shrink-0 md:flex-shrink-0" data-app-hidden="">
# <button class="flex items-center text-black text-black text-s p-16 outline-focus" data-navbar-el="menuActivator" title="Menü">
# <span class="leading-none relative top-px" data-body-el="scrollThreshold"><svg aria-labelledby="title-bd0c33ed-ee66-42ee-92a2-76898f351066" class="stroke-current" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-bd0c33ed-ee66-42ee-92a2-76898f351066">Icon: Menü</title><g id="l-menu-bd0c33ed-ee66-42ee-92a2-76898f351066" stroke-linecap="round" stroke-width="1.3"><path d="M19.35 6.65H4.65" id="line-bd0c33ed-ee66-42ee-92a2-76898f351066"></path><path d="M19.35 11.65H4.65" id="line_2-bd0c33ed-ee66-42ee-92a2-76898f351066"></path><path d="M19.35 16.65H4.65" id="line_3-bd0c33ed-ee66-42ee-92a2-76898f351066"></path></g></svg>
# </span>
# <span class="ml-8 relative">Menü</span>
# </button>
# </div>
# <div class="sm:hidden h-full lg:py-16 md:py-16 sm:py-8" data-app-hidden="">
# <div class="border-separator-r w-px h-full"></div>
# </div>
# <div class="relative lg:h-56 md:h-56 sm:h-40 focus:outline-none w-4 hidden select-none" data-swiper-el="prevEl">
# <div class="z-10 absolute left-0 bottom-0 lg:h-56 md:h-56 sm:h-40">
# <div class="flex items-center">
# <span class="md:hidden sm:hidden bg-white w-48 py-18 text-center cursor-pointer"><svg aria-labelledby="title-842630fe-56d5-4837-a860-3d775004f56f" class="stroke-current" fill="none" height="12" role="img" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg"><title id="title-842630fe-56d5-4837-a860-3d775004f56f">Pfeil nach links</title><g id="s-chevron-left-f-842630fe-56d5-4837-a860-3d775004f56f"><g id="s-chevron-right-f-842630fe-56d5-4837-a860-3d775004f56f"><g id="s-chevron-right-842630fe-56d5-4837-a860-3d775004f56f"><path d="M7.667 9.333L4.333 6l3.334-3.333" id="vector-842630fe-56d5-4837-a860-3d775004f56f" stroke-linecap="round" stroke-width="1.5"></path></g></g></g></svg>
# </span>
# <span class="bg-rightToLeft w-24 lg:h-56 md:h-56 sm:h-40"></span>
# </div>
# </div>
# </div>
# <nav class="swiper-container flex-grow relative overflow-hidden h-full bottom-negative" role="navigation" style="bottom:-8px;">
# <ul class="swiper-wrapper relative flex items-center bottom-8">
# <li class="swiper-slide flex-shrink-0">
# <a class="focus:border-black hover:border-shade-light border-transparent inline-flex items-center text-black text-s pl-16 px-4 lg:py-20 md:py-20 sm:py-12" href="https://www.spiegel.de/" target="_self" title="Startseite">
# <span class="border-b whitespace-no-wrap border-inherit">
# Startseite
# </span>
# <span class="leading-none ml-8"><svg aria-labelledby="title-5941008b-728e-4124-8fca-1b2cea90b57a" class="stroke-current" fill="none" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><title id="title-5941008b-728e-4124-8fca-1b2cea90b57a">Pfeil nach rechts</title><g id="m-chevron-right-5941008b-728e-4124-8fca-1b2cea90b57a"><path d="M6 4l4 4-4 4" id="vector-5941008b-728e-4124-8fca-1b2cea90b57a" stroke-linecap="round"></path></g></svg>
# </span>
# </a>
# </li>
# <li class="swiper-slide flex-shrink-0">
# <a class="focus:border-black hover:border-shade-light border-transparent inline-flex items-center text-black text-s px-4 lg:py-20 md:py-20 sm:py-12" href="https://www.spiegel.de/politik/" target="_self" title="Politik">
# <span class="border-b whitespace-no-wrap border-inherit">
# Politik
# </span>
# <span class="leading-none ml-8"><svg aria-labelledby="title-ea86a307-920e-4aaf-ae8c-a9a63094e6d0" class="stroke-current" fill="none" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><title id="title-ea86a307-920e-4aaf-ae8c-a9a63094e6d0">Pfeil nach rechts</title><g id="m-chevron-right-ea86a307-920e-4aaf-ae8c-a9a63094e6d0"><path d="M6 4l4 4-4 4" id="vector-ea86a307-920e-4aaf-ae8c-a9a63094e6d0" stroke-linecap="round"></path></g></svg>
# </span>
# </a>
# </li>
# <li class="swiper-slide flex-shrink-0">
# <a class="focus:border-black hover:border-shade-light border-transparent inline-flex items-center text-black text-s px-4 lg:py-20 md:py-20 sm:py-12" href="https://www.spiegel.de/politik/ausland/" target="_self" title="Ausland">
# <span class="border-b whitespace-no-wrap border-inherit">
# Ausland
# </span>
# <span class="leading-none ml-8"><svg aria-labelledby="title-dc6a9734-247f-4950-a472-5509fc578153" class="stroke-current" fill="none" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><title id="title-dc6a9734-247f-4950-a472-5509fc578153">Pfeil nach rechts</title><g id="m-chevron-right-dc6a9734-247f-4950-a472-5509fc578153"><path d="M6 4l4 4-4 4" id="vector-dc6a9734-247f-4950-a472-5509fc578153" stroke-linecap="round"></path></g></svg>
# </span>
# </a>
# </li>
# <li class="swiper-slide flex-shrink-0">
# <a class="focus:border-black hover:border-shade-light border-transparent inline-flex items-center text-black text-s px-4 lg:py-20 md:py-20 sm:py-12" href="https://www.spiegel.de/thema/alexej_nawalny/" target="_self" title="Alexej Nawalny">
# <span class="border-b whitespace-no-wrap border-inherit">
# Alexej Nawalny
# </span>
# <span class="leading-none ml-8"><svg aria-labelledby="title-1190990a-19e9-43ae-9325-0c22bc4f28ba" class="stroke-current" fill="none" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><title id="title-1190990a-19e9-43ae-9325-0c22bc4f28ba">Pfeil nach rechts</title><g id="m-chevron-right-1190990a-19e9-43ae-9325-0c22bc4f28ba"><path d="M6 4l4 4-4 4" id="vector-1190990a-19e9-43ae-9325-0c22bc4f28ba" stroke-linecap="round"></path></g></svg>
# </span>
# </a>
# </li>
# <li class="swiper-slide flex-shrink-0">
# <h1 class="font-normal whitespace-no-wrap inline-block text-black text-s pl-4 pr-16 pb-4">
# Alexej Nawalny: Unterstützer provozieren Wladimir Putin mit Herzchen-Protest
# </h1>
# </li>
# </ul>
# </nav>
# <div class="relative lg:h-56 md:h-56 sm:h-40 focus:outline-none select-none hidden" data-swiper-el="nextEl">
# <div class="z-10 absolute right-0 bottom-0 lg:h-56 md:h-56 sm:h-40">
# <div class="flex items-center">
# <span class="bg-leftToRight w-24 lg:h-56 md:h-56 sm:h-40"></span>
# <span class="md:hidden sm:hidden bg-white w-48 text-center cursor-pointer py-20 leading-none"><svg aria-labelledby="title-150f1e8a-4041-465e-9cf4-0bac624e27ed" class="stroke-current" fill="none" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><title id="title-150f1e8a-4041-465e-9cf4-0bac624e27ed">Pfeil nach rechts</title><g id="m-chevron-right-150f1e8a-4041-465e-9cf4-0bac624e27ed"><path d="M6 4l4 4-4 4" id="vector-150f1e8a-4041-465e-9cf4-0bac624e27ed" stroke-linecap="round"></path></g></svg>
# </span>
# </div>
# </div>
# </div>
# <div class="sm:hidden h-full lg:py-16 md:py-16 sm:py-8" data-app-hidden="">
# <div class="border-separator-r w-px h-full"></div>
# </div>
# <form class="flex-none sm:hidden bg-white w-56" data-app-hidden="" data-search-el="form">
# <div data-search-el="toggle-container">
# <button class="focus-outline flex items-center text-black text-s h-56 pl-16" data-search-el="toggle">
# <span class="absolute opacity-none pointer-events-none">Suche öffnen</span><svg aria-labelledby="title-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476" class="stroke-current" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476">Icon: Suche</title><g id="l-search-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476"><g id="group-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476" stroke-width="1.3"><circle cx="10" cy="11" id="ellipse-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476" r="5.35"></circle><path d="M14 15l4.5 4.5" id="vector-c6e4e4d5-38f2-4aa3-a9ae-da932de7f476" stroke-linecap="round"></path></g></g></svg>
# </button>
# </div>
# <div aria-hidden="true" class="absolute opacity-none pointer-events-none hidden" data-search-el="input-container">
# <div class="border border-black flex items-center justify-end h-40 ml-16 mr-6 rounded overflow-hidden">
# <label class="absolute opacity-none pointer-events-none" for="search-input-field">spiegel.de durchsuchen ...</label>
# <input class="pl-12 text-s h-32 flex-grow outline-focus placeholder-shade-base" data-search-el="input" id="search-input-field" name="suchbegriff" placeholder="spiegel.de durchsuchen ..." role="search"/>
# <button class="flex items-center text-black text-s h-56 pr-8 pl-16 mr-px focus-outline" data-search-el="submit" title="Seite durchsuchen">
# <span class="absolute opacity-none pointer-events-none">Suche starten</span><svg aria-labelledby="title-6b578eee-6373-410a-a586-875ce26091fa" class="stroke-current" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><title id="title-6b578eee-6373-410a-a586-875ce26091fa">Icon: Suche</title><g id="l-search-6b578eee-6373-410a-a586-875ce26091fa"><g id="group-6b578eee-6373-410a-a586-875ce26091fa" stroke-width="1.3"><circle cx="10" cy="11" id="ellipse-6b578eee-6373-410a-a586-875ce26091fa" r="5.35"></circle><path d="M14 15l4.5 4.5" id="vector-6b578eee-6373-410a-a586-875ce26091fa" stroke-linecap="round"></path></g></g></svg>
# </button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <section aria-label="Eilmeldungen" class="hidden relative z-20" data-breakingnews="">
# <div class="absolute z-0 top-8 right-0 bottom-0 left-0 shadow"></div>
# <ul class="relative z-10 bg-attention" data-area="breaking-bar" data-breakingnews-el="list"></ul>
# <ul class="hidden">
# <li class="w-full" data-breakingnews-prototype="default">
# <div class="OffsetContainer sm:max-w-sm md:max-w-md md:mx-auto sm:mx-auto">
# <a class="flex font-sansUI items-center justify-between lg:max-w-lg lg:px-32 lg:py-16 md:max-w-md md:px-24 md:py-16 mx-auto sm:max-w-sm sm:px-16 sm:py-12" href="#__proto_path__" title="__proto_headline__">
# <span class="lg:text-base md:text-base sm:text-s font-bold">
# <span class="uppercase pr-4">EILMELDUNG</span> —
# <span class="pl-4">__proto_headline__</span>
# </span>
# ...
# ;if(7303==n.p&&s.x>=n.x&&s.x<n.x+n.w&&s.y>=n.y&&s.y<n.y+n.h){if(n.u){var r=n.t.length>0?n.t:"_self";r=0==e.button&&e.ctrlKey?"_blank":r,zt(t,n.u,n.u,r,!0)}return}}var o=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2f68:8hfh50fh4h70583:0643806hig6<"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv28<73:4;i70ffh;60gi8904e3405:6;<f"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],h=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2h39647i570gf;460f4<:05hi<09h:686"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv288h<<ghh7054<<50e6h8076:<063gge;"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],l=o[1*f(2*s.y/this.offsetHeight)+f(1*s.x/this.offsetWidth)],d=h[1*f(2*s.y/this.offsetHeight)+f(1*s.x/this.offsetWidth)];zt(t,l,d,"_blank")}}),B(r,s),n.firstChild?nt(n.firstChild,r):B(n,r),t.stetwd53c4.a[7303]=r,C([{function:function(t,e){var s=setInterval(function(){var e=gt(".sfaobjm2");e&&(clearInterval(s),xt(e,"beforeBegin",t),lt(t,"stetwHid"),e.className=e.className+" stetwHid")},250)}}],r,7303),Ot(r,7303,kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2944e:<6e50;58g5058f90f7:<0;74<e6"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)),O(7303,e,!0)}}},function(){O(7303,e,!1)})}function z(e){Dt||ut(kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv266g66<e;508<57504<<90eg4806ehfdd"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),function(){if(!Dt){Dt=!0;var s=this;if(s.height<2)return void O(7249,e,!1);if(R==t.stetw6a8Rnd){var n=At,r=_("div");i[""+j(kt(j("WDM0RVhvVUpVWFlIW31Ud1E0O3toR0xA"),-3))]=r,dt(r,"ZbkURYzL"),ft(r,"xCnvlaT stetwHid");var h=s;t.stetwb95Am[7249]&&(I(t.stetwb95Am[7249]),t.stetwb95Am[7249]=!1),o(h,function(e,s){if(!t.stetwa7bPc[7249]){e.preventDefault(),e.stopPropagation();for(var s=a(e,this),i=0;i<t.stetw481Oc.length;i++){var n=t.stetw481Oc[i];if(7249==n.p&&s.x>=n.x&&s.x<n.x+n.w&&s.y>=n.y&&s.y<n.y+n.h){if(n.u){var r=n.t.length>0?n.t:"_self";r=0==e.button&&e.ctrlKey?"_blank":r,zt(t,n.u,n.u,r,!0)}return}}var o=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2439h:48670igh360;95905:980f878e7"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv273i<6:9i;08:;:60ge690:ef<0f56<54"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],h=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2g;36:8i9505g9360g95809f8<0h<8hfi"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2;g6:4hg870ehg760g5e809h480f5;:h5"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],l=o[2*f(1*s.y/this.offsetHeight)+f(2*s.x/this.offsetWidth)],d=h[2*f(1*s.y/this.offsetHeight)+f(2*s.x/this.offsetWidth)];zt(t,l,d,"_blank")}}),B(r,s),n.firstChild?nt(n.firstChild,r):B(n,r),t.stetwd53c4.a[7249]=r,C([{function:function(t,e){var s=setInterval(function(){var e=gt(".sfaobj3, .sfaobjp3");e&&(clearInterval(s),xt(e,"beforeBegin",t),lt(t,"stetwHid"),e.className=e.className+" stetwHid")},250)}}],r,7249),Ot(r,7249,kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2875g::6890e3i86073990;g4<09f9g4f"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)),O(7249,e,!0)}}},function(){O(7249,e,!1)})}function M(e){Ct||ut(kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2ge;5:5i7;0g63570gi6:06ei<03i793<"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),function(){if(!Ct){Ct=!0;var s=this;if(s.height<2)return void O(7304,e,!1);if(R==t.stetw6a8Rnd){var n=Tt,r=_("div");i[""+j(kt(j("WDM0RVhvVUpVWFlIW31Ud1E0PFFlNU1zZUpYQA=="),-3))]=r,ft(r,"FXitvGRogM stetwHid");var h=s;t.stetwb95Am[7304]&&(I(t.stetwb95Am[7304]),t.stetwb95Am[7304]=!1),o(h,function(e,s){if(!t.stetwa7bPc[7304]){e.preventDefault(),e.stopPropagation();for(var s=a(e,this),i=0;i<t.stetw481Oc.length;i++){var n=t.stetw481Oc[i];if(7304==n.p&&s.x>=n.x&&s.x<n.x+n.w&&s.y>=n.y&&s.y<n.y+n.h){if(n.u){var r=n.t.length>0?n.t:"_self";r=0==e.button&&e.ctrlKey?"_blank":r,zt(t,n.u,n.u,r,!0)}return}}var o=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2986<<g5h50g6f550g89:0i3e8076hg6g"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1g ...
# ;t.stetwb95Am[5830]&&(I(t.stetwb95Am[5830]),t.stetwb95Am[5830]=!1),o(h,function(e,s){if(!t.stetwa7bPc[5830]){e.preventDefault(),e.stopPropagation();for(var s=a(e,this),i=0;i<t.stetw481Oc.length;i++){var n=t.stetw481Oc[i];if(5830==n.p&&s.x>=n.x&&s.x<n.x+n.w&&s.y>=n.y&&s.y<n.y+n.h){if(n.u){var r=n.t.length>0?n.t:"_self";r=0==e.button&&e.ctrlKey?"_blank":r,zt(t,n.u,n.u,r,!0)}return}}var o=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2:;656;5;70h:8;50g;6:0hhi40g69d85"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2936i<466;04f8860i55:0633407gf3g:"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv24i946;<f90hegh608i6806e480d733d4"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],h=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2:73h8:89;0497g6083e:077<40gg:h4g"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2646<:8g7506eh9508<g90f7<80:7hd37"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2fhg44e5:90<59e50;6490f::803e4354"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],l=o[1*f(3*s.y/this.offsetHeight)+f(1*s.x/this.offsetWidth)],d=h[1*f(3*s.y/this.offsetHeight)+f(1*s.x/this.offsetWidth)];zt(t,l,d,"_blank")}}),B(r,s),nt(n,r),t.stetwd53c4.a[5830]=r,C([{applyAdText:!0}],r,5830),Ot(r,5830,kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2788<86::70f:3550483906g580h<98ge"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)),O(5830,e,!0)}}},function(){O(5830,e,!1)})}(!0)}else O(5830,!D,!1)}else O(5830,!D,!1);var D=!1;if(t.stetwf2eMobile)O(568,!D,!1);else{var it=n[""+j(kt(j("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))],rt=!1;if(it){var R=t.stetw6a8Rnd;!function(e){rt||ut(kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2794:6h:870777760g<e908eg40<:85e6"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),function(){if(!rt){rt=!0;var s=this;if(s.height<2)return void O(568,e,!1);if(R==t.stetw6a8Rnd){var n=it,r=_("div");i[""+j(kt(j("WDN3XVs0TXNdNWsz"),-3))]=r,ft(r,"DNovJtXG ");var h=s;t.stetwb95Am[568]&&(I(t.stetwb95Am[568]),t.stetwb95Am[568]=!1),o(h,function(e,s){if(!t.stetwa7bPc[568]){e.preventDefault(),e.stopPropagation();for(var s=a(e,this),i=0;i<t.stetw481Oc.length;i++){var n=t.stetw481Oc[i];if(568==n.p&&s.x>=n.x&&s.x<n.x+n.w&&s.y>=n.y&&s.y<n.y+n.h){if(n.u){var r=n.t.length>0?n.t:"_self";r=0==e.button&&e.ctrlKey?"_blank":r,zt(t,n.u,n.u,r,!0)}return}}var o=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv245954:9i508:f;709;680fig80d77<f:"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2:;;;<hei70gh8770<:7:06;880eg;f66"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2<9if674<;0g<4;709i:80i8g803i93d8"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2<gif664590448e707ih:0;8440g<g9:5"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2f978899g;0ihi:70475804hh<0ede8i6"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv245:i85f850f8if50:6e:09;6<048:9i;"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],h=[kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2<3f5447f;043g:7057g:0:9i4079<e;i"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv286f6<<9790838;50e6<90e3:<03;i585"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2hf<7:;;590e:ei60e8790533<0de7fdg"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2:fg747<:707f3g604<390:ee409g;934"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2fhe<44e<904f97505:i908f44038649<"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3),kt("22fgq1surg1zzz1vslhjho1gh2lpdjhv2953i64fg9055;<6057e80e6:80968de4"+t.stetw6a8Rnd+"bz<43kb933bis{5<1<8bis|771<71msj",-3)],l=o[1*f(6*s.y/this.offsetHeight)+f(1*s.x/this.offsetWidth)],d=h[1*f(6*s.y/this.offsetHeig ...
# }else if("am"==s.c)t.stetwd53c4.a[s.d.i]?I(s.d.u):t.stetwb95Am[s.d.i]=s.d.u;else if("pc"==s.c)t.stetwa7bPc[s.d]=!0;else if("ev"==s.c)t.stetwf49Ev[s.d]=!0;else if("oc"==s.c)t.stetw481Oc.push(s.d);else if("ac"==s.c){var h=gt(s.d.slc),n=_("div");n.innerHTML=s.d.cnt,jt(n.childNodes,function(t,e){h.appendChild(e)})}else if("js"==s.c){var n=_("script");B(Gt,n),G(n,s.d)}else if("if"==s.c){var n=_("iframe");n.src=s.d,n.style.display="none",B(Gt,n)}else if("img"==s.c)var f=function(){this.style.display="none"},o=bt(s.d,f,f,Gt)}catch(t){}},!1),t.TDORVdd=V,t.stetw5d5Flags={},t.stetw5d5Flags.welect={};var Qt=!0;if(t.stetw6a8Rnd=t.stetw6a8Rnd||Q(),!function(){return t.stetw5d5Flags.crt=!0,t.stetw5d5Flags.nwc2flst=!0,t.stetw5d5Flags.video=/video=true/.test(location.search),t.stetw5d5Flags.gnrcfll=!1,!0}())return;var Pt;z(t,"message",function(e){var s=e&&e.data;if(s&&"video"===s.from&&"main"===s.to){Pt=e.source;var i=s.message&&s.message.type;s.message&&s.message.value;switch(i){case"detection":var n=L(function(){t.stetwd53ctc&&t.stetw5feTrack&&(m(n),Pt.postMessage({from:"main",to:"video",message:{type:i,value:t.stetwd53ctc.ab||t.stetwd53ctc.gn||t.stetwd53ctc.pm}}))},500)}}}),t.stetw5d5Flags.video&&function(t,e){function s(t,e){var s;return e.filter(function(e){return s=new RegExp(e),s.test(t)}).length>0}function i(e,s){if(!e||!e instanceof t.String)return"";var i,n=e.split("?"),r=n[0].split("/");return i=e.indexOf("://")>-1?r[0]+"//"+r[2]:0===e.indexOf("//")?t.location.protocol+"//"+r[2]:t.location.origin,s?e.indexOf("imasdk.googleapis.com/js/core/bridge")>-1?e.replace("core","sdkloader"):(i=r.length>3?i+"/"+r[r.length-1]:i,n[0]=i,i=n.join("?")):i}function n(e){return e&&i(e)&&i(e)!==t.location.origin}function r(){return P()}function a(t,e,s,i){i=i||!1,z(t,"load",e,i),z(t,"error",s,i)}function o(t,e,s){ot(t,"load",e),ot(t,"error",s)}function l(){var e=".DsznQkmM, #DsznQkmM";return t.stetw5d5Flags&&void 0!==t.stetw5d5Flags.extraPlayerSelectors&&(e=[e].concat(t.stetw5d5Flags.extraPlayerSelectors).join(", ")),e}function d(){var e=["imasdk.googleapis.com/js/sdkloader/","/integrator.js","/client.js","smartclip.net/","/vpaid.js","geo.moatads.com/n.js","cdn.doubleverify.com/dv-measurements","pixel.adsafeprotected.com/jload","static.adsafeprotected.com/main","/vast.js"];return t.stetw5d5Flags&&void 0!==t.stetw5d5Flags.extraVideoAdRelatedScriptNames&&(e=e.concat(t.stetw5d5Flags.extraVideoAdRelatedScriptNames)),e}function g(){var e="^https?://serv.vid-play.com/api/adserver/tag/|^https?://call.inforsea.com/adserver/sources";return t.stetw5d5Flags&&void 0!==t.stetw5d5Flags.extraAdTagRegExpStrs&&(e=[e].concat(t.stetw5d5Flags.extraAdTagRegExpStrs).join("|")),new RegExp(e)}function u(){var e=!1;return t.stetw5d5Flags&&void 0!==t.stetw5d5Flags.useNoAdNoContent&&(e=t.stetw5d5Flags.useNoAdNoContent),e}function b(){var e=!0;return t.stetw5d5Flags&&void 0!==t.stetw5d5Flags.noAdNoContentDebug&&(e=t.stetw5d5Flags.noAdNoContentDebug),e}function w(e){var s,i=L(function(){if(!e.isConnected)return void m(i);if(q()&&nt&&e.hasAttribute("href")){ot(e,"click",s,!0);var n=J(e,"href");if(n){K(e,"href");var r="_blank";e.hasAttribute("target")&&(r=J(e,"target"),K(e,"target")),s=function(e){t.open(n,r)},z(e,"click",s,!0)}}},500)}function M(s,i,n,r,a){function o(t){z(t.element,"load",t.onLoad),z(t.element,"error",t.onError)}function f(t){ot(t.element,"load",t.onLoad),ot(t.element,"error",t.onError)}function l(t){return tt.successfulTests.indexOf(t.name)>-1}function d(t){return tt.failedTests.indexOf(t.name)>-1}function g(t){return tt.successfulTests.push(t.name)}function c(t){return tt.failedTests.push(t.name)}function u(t){switch(t.start=Date.now(),t.name){case F.name:D(3e3);case E.name:case W.name:case V.name:t.element.src=t.url;break;case q.name:var e=t.element;t.element=e.ownerDocument.createElement("script"),t.element.src=t.url,t.element.onload=function(){yt(e,"load")},t.element.onerror=function(){yt(e,"error")},B(e.parentNode,t.element);break;case U.name:t.element.open( ...
# </script>
# <script async="" src="//assets.adobedtm.com/launch-ENd63cd063bc184946bf26f6f38bb5c4ed.min.js"></script>
# </body>
# </html>

# %%
# 1
browser = mechanicalsoup.Browser()
url = "http://olympus.realpython.org/login"
login_page = browser.get(url)
login_html = login_page.soup

# 2
form = login_html.select("form")[0]
form.select("input")[0]["value"] = "zeus"
form.select("input")[1]["value"] = "ThunderDude"

# 3
profiles_page = browser.submit(form, login_page.url)

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

#url = "http://olympus.realpython.org/profiles/dionysus"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
#print(soup.get_text())
raw_html = soup.prettify()

# %%
soup.contents[2].name
# u'html'

titleTag = soup.html.head.title
titleTag
# Out:
# <title>Osterurlaub: Streit über Lockerungen für Reiseverkehr im Frühling - WELT</title>

# %%
titleTag.string
# Out:
# 'Osterurlaub: Streit über Lockerungen für Reiseverkehr im Frühling - WELT'

# %%
soup.contents[0].contents[0].name
# u'head'

head = soup.contents[0].contents[0]
head.parent.name
# u'html'
